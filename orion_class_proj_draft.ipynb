# %% [markdown]
# ### Home - Here is our project

# %%
#imports

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# statistics for harmonic_mean
import statistics as s

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from graphviz import *

from acquire import *
from prepare import *

df = get_telco_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
# customer_id                 7043 non-null object
# gender                      7043 non-null object
# senior_citizen              7043 non-null int64
# partner                     7043 non-null object
# dependents                  7043 non-null object
# tenure                      7043 non-null int64
# phone_service               7043 non-null object
# multiple_lines              7043 non-null object
# internet_service_type_id    7043 non-null int64
# online_security             7043 non-null object
# online_backup               7043 non-null object
# device_protection           7043 non-null object
# tech_support                7043 non-null object
# streaming_tv                7043 non-null object
# streaming_movies            7043 non-null object
# contract_type_id            7043 non-null int64
# paperless_billing           7043 non-null object
# ...

# %%
def peekatdata(df):
    head_df = df.head(5)
    print(head_df)
    tail_df = df.tail(5)
    print(tail_df)
    shape_tuple = df.shape
    print(shape_tuple)
    describe_df = df.describe()
    print(describe_df)
    df.info()

# %%
def prep_telco_data(df):
    df['total_charges'] = df['total_charges'].convert_objects(convert_numeric=True)
    for col in df.drop(columns=(['customer_id', 'total_charges', 'monthly_charges'])):
        print('encoding ' + col)
        encoder = LabelEncoder()
        encoder.fit(df[col])
        new_col = col + '_e'
        df[new_col] = encoder.transform(df[col])
    return df

# %%
prep_telco_data(df)
# Out:
# encoding gender
# encoding senior_citizen
# encoding partner
# encoding dependents
# encoding tenure
# encoding phone_service
# encoding multiple_lines
# encoding internet_service_type_id
# encoding online_security
# encoding online_backup
# encoding device_protection
# encoding tech_support
# encoding streaming_tv
# encoding streaming_movies
# encoding contract_type_id
# encoding paperless_billing
# encoding payment_type_id
# encoding churn
# encoding contract_type
# encoding internet_service_type
# encoding payment_type
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0003-MKNFE    Male               0      No         No       9
# 1     0013-MHZWF  Female               0      No        Yes       9
# 2     0015-UOCOJ  Female               1      No         No       7
# 3     0023-HGHWL    Male               1      No         No       1
# 4     0032-PGELS  Female               0     Yes        Yes       1
# ...

# %%
df1 = df.loc[:, ~df.columns.str.endswith('_e')]
df1 = df1.apply(df[['customer_id', 'monthly_charges', 'total_charges']])
df1.shape
df.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-fe5c3fc142c0> in <module>
#       1 df1 = df.loc[:, ~df.columns.str.endswith('_e')]
# ----> 2 df1 = df1.apply(df[['customer_id', 'monthly_charges', 'total_charges']])
#       3 df1.shape
#       4 df.shape
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
# ...

# %%
df1.shape
# Out:
# (14086, 24)

# %%
df1.sample(15)
# Out:
#      churn   contract_type  contract_type_id customer_id dependents  \
# 3650    No  Month-to-month               1.0  5606-AMZBO         No
# 5907    No  Month-to-month               1.0  7302-ZHMHP         No
# 5763   NaN             NaN               NaN  4488-PSYCG        NaN
# 3759   Yes  Month-to-month               1.0  6110-OHIHY         No
# 2251    No        Two year               3.0  7349-ALMUX         No
# 1193    No  Month-to-month               1.0  9700-ISPUP        Yes
# 96     NaN             NaN               NaN  0867-LDTTC        NaN
# 2862   NaN             NaN               NaN  2133-TSRRM        NaN
# 6119    No        One year               2.0  2351-RRBUE        Yes
# 4317    No  Month-to-month               1.0  8903-WMRNW         No
# 3575   NaN             NaN               NaN  5299-RULOA        NaN
# 3312    No  Month-to-month               1.0  4138-NAXED         No
# 6605    No        Two year               3.0  3115-CZMZD        Yes
# ...

# %%
for col in df['partner', 'dependents', 'phone_service',
              'online_security', 'streaming_movies',
              'paperless_billing', 'churn']:
    df[col] = df[col].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
# def df_value_counts(df):
for col in df.drop(columns=('customer_id')):
    if np.issubdtype(df[col].dtype, np.number) and df[col].nunique() > 10:
        print(df[col].value_counts(bins=10, sort=False))
    else:
        print(df[col].value_counts(sort=False))

# %%
df[(df.select_dtypes(include=['number']) == 0).any(1)]

# %% [markdown]
# Convert all string labels to numeric

# %%
df['gender'] = df['gender'].replace({'Male': 1, 'Female': 0})
df['contract_type'] = df['contract_type'].replace({'Month-to-month': 0, 'One year': 1, 'Two year': 2})


to_bool = df[['partner', 'dependents', 'phone_service', 'online_security',
             'online_backup', 'device_protection', 'tech_support', 'streaming_tv',
             'streaming_movies', 'paperless_billing', 'churn']]

for col in to_bool:
    df[col] = df[col].replace({'Yes': 1, 'No': 0})
